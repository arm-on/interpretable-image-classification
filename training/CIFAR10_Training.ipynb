# %% [markdown]
# In this notebook, we train a neural network to classify the images of the CIFAR10 dataset

# %% [markdown]
# Google Drive Authentication
# ---

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# %cd /gdrive/My Drive/IIC/
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/DrRabiee-Project

# %% [markdown]
# Importing the Necessary Libraries
# ---

# %%
from __future__ import print_function
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import optimizers
from tensorflow import expand_dims
import numpy as np
from tensorflow.keras.layers import Lambda
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %% [markdown]
# Configuration
# ---

# %%
num_classes = 10
weight_decay = 0.0005
x_shape = [32,32,3]
batch_size = 128
maxepoches = 250
learning_rate = 0.1
lr_decay = 1e-6
lr_drop = 20

# %% [markdown]
# Model Architecture
# ---

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same',
                    input_shape=x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_14 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_17 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_18 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_19 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# activation_21 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_22 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_23 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_24 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_25 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_26 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_27 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_28 (Activation)   (None, 10)                0
# =================================================================
# Total params: 15,001,418
# Trainable params: 14,991,946
# Non-trainable params: 9,472
# _________________________________________________________________

# %% [markdown]
# Loading the Data
# ---

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# Normalizing the Data
# ---

# %%
def normalize(X_train,X_test):
    # this function normalizes inputs so that they have zero mean and unit variance
    # it is used when training a model
    # Input: training set and test set
    # Output: normalized training set and test set according to the trianing set statistics.
    mean = np.mean(X_train,axis=(0,1,2,3))
    std = np.std(X_train, axis=(0, 1, 2, 3))
    X_train = (X_train-mean)/(std+1e-7)
    X_test = (X_test-mean)/(std+1e-7)
    return X_train, X_test

# %%
x_train, x_test = normalize(x_train, x_test)

# %% [markdown]
# Performing one-hot encoding on the labels
# ---

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Data Augmentation
# ---

# %%
datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)  # randomly flip images
        # (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# %% [markdown]
# Scheduling the Learning Rate
# ---

# %%
def lr_scheduler(epoch):
    return learning_rate * (0.5 ** (epoch // lr_drop))
reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

# %% [markdown]
# Compiling the Model
# ---

# %%
sgd = optimizers.SGD(learning_rate=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %% [markdown]
# Training the Model
# ---

# %%
historytemp = model.fit_generator(datagen.flow(x_train, y_train,
                                    batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=maxepoches,
                    validation_data=(x_test, y_test),callbacks=[reduce_lr],verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/250
# 390/390 [==============================] - 98s 169ms/step - loss: 22.9559 - accuracy: 0.1781 - val_loss: 16.6303 - val_accuracy: 0.1248
# Epoch 2/250
# 390/390 [==============================] - 63s 161ms/step - loss: 11.7948 - accuracy: 0.2700 - val_loss: 9.1476 - val_accuracy: 0.1551
# Epoch 3/250
# 390/390 [==============================] - 63s 161ms/step - loss: 6.3164 - accuracy: 0.3684 - val_loss: 5.0986 - val_accuracy: 0.2870
# Epoch 4/250
# 390/390 [==============================] - 63s 161ms/step - loss: 3.7369 - accuracy: 0.4644 - val_loss: 3.4148 - val_accuracy: 0.3688
# Epoch 5/250
# 390/390 [==============================] - 63s 161ms/step - loss: 2.5123 - accuracy: 0.5360 - val_loss: 2.4496 - val_accuracy: 0.4941
# Epoch 6/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.9347 - accuracy: 0.5917 - val_loss: 1.9396 - val_accuracy: 0.5808
# Epoch 7/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.6592 - accuracy: 0.6335 - val_loss: 1.9339 - val_accuracy: 0.5747
# Epoch 8/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.5533 - accuracy: 0.6529 - val_loss: 1.5978 - val_accuracy: 0.6440
# Epoch 9/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.5226 - accuracy: 0.6728 - val_loss: 1.4103 - val_accuracy: 0.7072
# Epoch 10/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4790 - accuracy: 0.6879 - val_loss: 1.4364 - val_accuracy: 0.7034
# Epoch 11/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4642 - accuracy: 0.7007 - val_loss: 1.5079 - val_accuracy: 0.6864
# Epoch 12/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4753 - accuracy: 0.7049 - val_loss: 1.5239 - val_accuracy: 0.6915
# Epoch 13/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4716 - accuracy: 0.7152 - val_loss: 1.5492 - val_accuracy: 0.6982
# Epoch 14/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4660 - accuracy: 0.7193 - val_loss: 1.4363 - val_accuracy: 0.7328
# Epoch 15/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4693 - accuracy: 0.7238 - val_loss: 1.4154 - val_accuracy: 0.7485
# Epoch 16/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4789 - accuracy: 0.7256 - val_loss: 1.4158 - val_accuracy: 0.7465
# Epoch 17/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.4848 - accuracy: 0.7318 - val_loss: 1.3912 - val_accuracy: 0.7642
# Epoch 18/250
# 390/390 [==============================] - 63s 162ms/step - loss: 1.4988 - accuracy: 0.7316 - val_loss: 1.4708 - val_accuracy: 0.7420
# Epoch 19/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.5071 - accuracy: 0.7336 - val_loss: 1.4366 - val_accuracy: 0.7662
# Epoch 20/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.5096 - accuracy: 0.7372 - val_loss: 1.4837 - val_accuracy: 0.7412
# Epoch 21/250
# 390/390 [==============================] - 63s 160ms/step - loss: 1.3329 - accuracy: 0.7768 - val_loss: 1.1947 - val_accuracy: 0.8083
# Epoch 22/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2360 - accuracy: 0.7857 - val_loss: 1.1243 - val_accuracy: 0.8164
# Epoch 23/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2086 - accuracy: 0.7844 - val_loss: 1.1564 - val_accuracy: 0.7918
# Epoch 24/250
# 390/390 [==============================] - 63s 160ms/step - loss: 1.2013 - accuracy: 0.7851 - val_loss: 1.1189 - val_accuracy: 0.8128
# Epoch 25/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2033 - accuracy: 0.7874 - val_loss: 1.2008 - val_accuracy: 0.7924
# Epoch 26/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.1985 - accuracy: 0.7894 - val_loss: 1.2008 - val_accuracy: 0.7924
# Epoch 27/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2066 - accuracy: 0.7906 - val_loss: 1.1555 - val_accuracy: 0.8129
# Epoch 28/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2066 - accuracy: 0.7952 - val_loss: 1.1001 - val_accuracy: 0.8259
# Epoch 29/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2107 - accuracy: 0.7953 - val_loss: 1.2249 - val_accuracy: 0.7910
# Epoch 30/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2100 - accuracy: 0.7973 - val_loss: 1.2189 - val_accuracy: 0.7964
# Epoch 31/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2133 - accuracy: 0.7978 - val_loss: 1.1416 - val_accuracy: 0.8314
# Epoch 32/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2221 - accuracy: 0.7975 - val_loss: 1.1903 - val_accuracy: 0.8073
# Epoch 33/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2206 - accuracy: 0.8004 - val_loss: 1.1168 - val_accuracy: 0.8298
# Epoch 34/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2173 - accuracy: 0.8021 - val_loss: 1.1622 - val_accuracy: 0.8216
# Epoch 35/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2271 - accuracy: 0.8010 - val_loss: 1.1194 - val_accuracy: 0.8362
# Epoch 36/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2227 - accuracy: 0.8036 - val_loss: 1.2065 - val_accuracy: 0.8095
# Epoch 37/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2261 - accuracy: 0.8027 - val_loss: 1.2064 - val_accuracy: 0.8154
# Epoch 38/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2286 - accuracy: 0.8046 - val_loss: 1.1777 - val_accuracy: 0.8241
# Epoch 39/250
# 390/390 [==============================] - 63s 162ms/step - loss: 1.2289 - accuracy: 0.8042 - val_loss: 1.1744 - val_accuracy: 0.8231
# Epoch 40/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.2276 - accuracy: 0.8069 - val_loss: 1.2243 - val_accuracy: 0.8020
# Epoch 41/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.0997 - accuracy: 0.8377 - val_loss: 0.9747 - val_accuracy: 0.8686
# Epoch 42/250
# 390/390 [==============================] - 63s 161ms/step - loss: 1.0228 - accuracy: 0.8493 - val_loss: 0.9506 - val_accuracy: 0.8641
# Epoch 43/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.9950 - accuracy: 0.8447 - val_loss: 0.9644 - val_accuracy: 0.8557
# Epoch 44/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9708 - accuracy: 0.8501 - val_loss: 0.9039 - val_accuracy: 0.8661
# Epoch 45/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.9659 - accuracy: 0.8476 - val_loss: 0.8774 - val_accuracy: 0.8746
# Epoch 46/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.9527 - accuracy: 0.8480 - val_loss: 0.9400 - val_accuracy: 0.8518
# Epoch 47/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.9569 - accuracy: 0.8461 - val_loss: 0.9402 - val_accuracy: 0.8536
# Epoch 48/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.9571 - accuracy: 0.8470 - val_loss: 0.9279 - val_accuracy: 0.8578
# Epoch 49/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9570 - accuracy: 0.8482 - val_loss: 0.9049 - val_accuracy: 0.8641
# Epoch 50/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9589 - accuracy: 0.8477 - val_loss: 0.8996 - val_accuracy: 0.8642
# Epoch 51/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9620 - accuracy: 0.8462 - val_loss: 0.9709 - val_accuracy: 0.8441
# Epoch 52/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9603 - accuracy: 0.8487 - val_loss: 0.8945 - val_accuracy: 0.8713
# Epoch 53/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9598 - accuracy: 0.8482 - val_loss: 0.8947 - val_accuracy: 0.8664
# Epoch 54/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9624 - accuracy: 0.8503 - val_loss: 0.9804 - val_accuracy: 0.8453
# Epoch 55/250
# 390/390 [==============================] - 67s 172ms/step - loss: 0.9644 - accuracy: 0.8502 - val_loss: 0.9240 - val_accuracy: 0.8560
# Epoch 56/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9655 - accuracy: 0.8510 - val_loss: 0.8963 - val_accuracy: 0.8749
# Epoch 57/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9596 - accuracy: 0.8500 - val_loss: 0.9201 - val_accuracy: 0.8651
# Epoch 58/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9667 - accuracy: 0.8498 - val_loss: 0.9053 - val_accuracy: 0.8727
# Epoch 59/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9611 - accuracy: 0.8513 - val_loss: 0.9284 - val_accuracy: 0.8676
# Epoch 60/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.9584 - accuracy: 0.8534 - val_loss: 0.8986 - val_accuracy: 0.8750
# Epoch 61/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.8804 - accuracy: 0.8752 - val_loss: 0.7963 - val_accuracy: 0.8979
# Epoch 62/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.8258 - accuracy: 0.8861 - val_loss: 0.7740 - val_accuracy: 0.8994
# Epoch 63/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.8005 - accuracy: 0.8886 - val_loss: 0.8118 - val_accuracy: 0.8837
# Epoch 64/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.7852 - accuracy: 0.8866 - val_loss: 0.7850 - val_accuracy: 0.8881
# Epoch 65/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7695 - accuracy: 0.8897 - val_loss: 0.7906 - val_accuracy: 0.8839
# Epoch 66/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7653 - accuracy: 0.8877 - val_loss: 0.7501 - val_accuracy: 0.8942
# Epoch 67/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7522 - accuracy: 0.8896 - val_loss: 0.7463 - val_accuracy: 0.8921
# Epoch 68/250
# 390/390 [==============================] - 67s 172ms/step - loss: 0.7465 - accuracy: 0.8894 - val_loss: 0.7291 - val_accuracy: 0.8930
# Epoch 69/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7504 - accuracy: 0.8876 - val_loss: 0.7585 - val_accuracy: 0.8861
# Epoch 70/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7432 - accuracy: 0.8861 - val_loss: 0.7078 - val_accuracy: 0.8973
# Epoch 71/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7417 - accuracy: 0.8878 - val_loss: 0.7244 - val_accuracy: 0.8973
# Epoch 72/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7338 - accuracy: 0.8903 - val_loss: 0.7483 - val_accuracy: 0.8872
# Epoch 73/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7389 - accuracy: 0.8866 - val_loss: 0.7133 - val_accuracy: 0.8977
# Epoch 74/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7400 - accuracy: 0.8861 - val_loss: 0.7418 - val_accuracy: 0.8893
# Epoch 75/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7326 - accuracy: 0.8910 - val_loss: 0.7721 - val_accuracy: 0.8839
# Epoch 76/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7400 - accuracy: 0.8862 - val_loss: 0.7595 - val_accuracy: 0.8849
# Epoch 77/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7380 - accuracy: 0.8895 - val_loss: 0.7703 - val_accuracy: 0.8845
# Epoch 78/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.7346 - accuracy: 0.8908 - val_loss: 0.7342 - val_accuracy: 0.8946
# Epoch 79/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.7362 - accuracy: 0.8900 - val_loss: 0.7625 - val_accuracy: 0.8815
# Epoch 80/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.7367 - accuracy: 0.8897 - val_loss: 0.7341 - val_accuracy: 0.8955
# Epoch 81/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.6775 - accuracy: 0.9078 - val_loss: 0.6734 - val_accuracy: 0.9113
# Epoch 82/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.6447 - accuracy: 0.9156 - val_loss: 0.6571 - val_accuracy: 0.9126
# Epoch 83/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.6293 - accuracy: 0.9171 - val_loss: 0.6824 - val_accuracy: 0.9057
# Epoch 84/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.6169 - accuracy: 0.9177 - val_loss: 0.6667 - val_accuracy: 0.9051
# Epoch 85/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.6085 - accuracy: 0.9199 - val_loss: 0.6426 - val_accuracy: 0.9125
# Epoch 86/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.6004 - accuracy: 0.9199 - val_loss: 0.6440 - val_accuracy: 0.9103
# Epoch 87/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.5901 - accuracy: 0.9227 - val_loss: 0.6323 - val_accuracy: 0.9113
# Epoch 88/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.5887 - accuracy: 0.9209 - val_loss: 0.6376 - val_accuracy: 0.9064
# Epoch 89/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.5824 - accuracy: 0.9204 - val_loss: 0.6359 - val_accuracy: 0.9097
# Epoch 90/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.5792 - accuracy: 0.9211 - val_loss: 0.6404 - val_accuracy: 0.9044
# Epoch 91/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.5770 - accuracy: 0.9212 - val_loss: 0.6252 - val_accuracy: 0.9086
# Epoch 92/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.5700 - accuracy: 0.9206 - val_loss: 0.5976 - val_accuracy: 0.9176
# Epoch 93/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.5662 - accuracy: 0.9227 - val_loss: 0.6010 - val_accuracy: 0.9139
# Epoch 94/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.5668 - accuracy: 0.9209 - val_loss: 0.6340 - val_accuracy: 0.9030
# Epoch 95/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.5654 - accuracy: 0.9212 - val_loss: 0.6251 - val_accuracy: 0.9061
# Epoch 96/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.5623 - accuracy: 0.9220 - val_loss: 0.5871 - val_accuracy: 0.9176
# Epoch 97/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.5620 - accuracy: 0.9216 - val_loss: 0.6218 - val_accuracy: 0.9081
# Epoch 98/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.5620 - accuracy: 0.9202 - val_loss: 0.6166 - val_accuracy: 0.9064
# Epoch 99/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.5574 - accuracy: 0.9230 - val_loss: 0.6069 - val_accuracy: 0.9106
# Epoch 100/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.5594 - accuracy: 0.9208 - val_loss: 0.6436 - val_accuracy: 0.8991
# Epoch 101/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.5234 - accuracy: 0.9331 - val_loss: 0.5619 - val_accuracy: 0.9237
# Epoch 102/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.4995 - accuracy: 0.9397 - val_loss: 0.5709 - val_accuracy: 0.9198
# Epoch 103/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4922 - accuracy: 0.9397 - val_loss: 0.5606 - val_accuracy: 0.9218
# Epoch 104/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.4786 - accuracy: 0.9434 - val_loss: 0.5565 - val_accuracy: 0.9232
# Epoch 105/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4735 - accuracy: 0.9424 - val_loss: 0.5643 - val_accuracy: 0.9219
# Epoch 106/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4702 - accuracy: 0.9442 - val_loss: 0.5668 - val_accuracy: 0.9189
# Epoch 107/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4709 - accuracy: 0.9417 - val_loss: 0.5603 - val_accuracy: 0.9208
# Epoch 108/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4612 - accuracy: 0.9446 - val_loss: 0.5434 - val_accuracy: 0.9218
# Epoch 109/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.4554 - accuracy: 0.9449 - val_loss: 0.5447 - val_accuracy: 0.9219
# Epoch 110/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.4538 - accuracy: 0.9451 - val_loss: 0.5442 - val_accuracy: 0.9223
# Epoch 111/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.4456 - accuracy: 0.9471 - val_loss: 0.5649 - val_accuracy: 0.9175
# Epoch 112/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.4459 - accuracy: 0.9465 - val_loss: 0.5486 - val_accuracy: 0.9212
# Epoch 113/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.4409 - accuracy: 0.9467 - val_loss: 0.5434 - val_accuracy: 0.9187
# Epoch 114/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4416 - accuracy: 0.9459 - val_loss: 0.5567 - val_accuracy: 0.9183
# Epoch 115/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4393 - accuracy: 0.9456 - val_loss: 0.5386 - val_accuracy: 0.9227
# Epoch 116/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4364 - accuracy: 0.9463 - val_loss: 0.5312 - val_accuracy: 0.9242
# Epoch 117/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4333 - accuracy: 0.9468 - val_loss: 0.5302 - val_accuracy: 0.9241
# Epoch 118/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4340 - accuracy: 0.9453 - val_loss: 0.5338 - val_accuracy: 0.9207
# Epoch 119/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.4268 - accuracy: 0.9478 - val_loss: 0.5427 - val_accuracy: 0.9176
# Epoch 120/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4250 - accuracy: 0.9484 - val_loss: 0.5340 - val_accuracy: 0.9196
# Epoch 121/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.4036 - accuracy: 0.9544 - val_loss: 0.5266 - val_accuracy: 0.9213
# Epoch 122/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3924 - accuracy: 0.9567 - val_loss: 0.5140 - val_accuracy: 0.9266
# Epoch 123/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.3883 - accuracy: 0.9580 - val_loss: 0.5198 - val_accuracy: 0.9240
# Epoch 124/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3818 - accuracy: 0.9586 - val_loss: 0.5220 - val_accuracy: 0.9244
# Epoch 125/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3750 - accuracy: 0.9613 - val_loss: 0.5167 - val_accuracy: 0.9280
# Epoch 126/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3737 - accuracy: 0.9606 - val_loss: 0.5190 - val_accuracy: 0.9271
# Epoch 127/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.3694 - accuracy: 0.9624 - val_loss: 0.5080 - val_accuracy: 0.9274
# Epoch 128/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3678 - accuracy: 0.9611 - val_loss: 0.5138 - val_accuracy: 0.9260
# Epoch 129/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3665 - accuracy: 0.9622 - val_loss: 0.5060 - val_accuracy: 0.9278
# Epoch 130/250
# 390/390 [==============================] - 67s 172ms/step - loss: 0.3626 - accuracy: 0.9624 - val_loss: 0.5147 - val_accuracy: 0.9253
# Epoch 131/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3598 - accuracy: 0.9632 - val_loss: 0.5034 - val_accuracy: 0.9284
# Epoch 132/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3544 - accuracy: 0.9633 - val_loss: 0.4943 - val_accuracy: 0.9289
# Epoch 133/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3583 - accuracy: 0.9621 - val_loss: 0.4911 - val_accuracy: 0.9301
# Epoch 134/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3532 - accuracy: 0.9636 - val_loss: 0.5065 - val_accuracy: 0.9260
# Epoch 135/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3523 - accuracy: 0.9628 - val_loss: 0.5003 - val_accuracy: 0.9270
# Epoch 136/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3467 - accuracy: 0.9647 - val_loss: 0.5037 - val_accuracy: 0.9253
# Epoch 137/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3422 - accuracy: 0.9653 - val_loss: 0.4998 - val_accuracy: 0.9255
# Epoch 138/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.3422 - accuracy: 0.9652 - val_loss: 0.4968 - val_accuracy: 0.9265
# Epoch 139/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3431 - accuracy: 0.9651 - val_loss: 0.5048 - val_accuracy: 0.9253
# Epoch 140/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3385 - accuracy: 0.9653 - val_loss: 0.4824 - val_accuracy: 0.9312
# Epoch 141/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.3314 - accuracy: 0.9674 - val_loss: 0.4812 - val_accuracy: 0.9301
# Epoch 142/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3221 - accuracy: 0.9700 - val_loss: 0.5002 - val_accuracy: 0.9265
# Epoch 143/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3194 - accuracy: 0.9708 - val_loss: 0.4944 - val_accuracy: 0.9291
# Epoch 144/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.3186 - accuracy: 0.9710 - val_loss: 0.4814 - val_accuracy: 0.9312
# Epoch 145/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.3169 - accuracy: 0.9702 - val_loss: 0.4852 - val_accuracy: 0.9290
# Epoch 146/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3122 - accuracy: 0.9719 - val_loss: 0.4844 - val_accuracy: 0.9304
# Epoch 147/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3124 - accuracy: 0.9713 - val_loss: 0.4822 - val_accuracy: 0.9323
# Epoch 148/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3088 - accuracy: 0.9723 - val_loss: 0.4817 - val_accuracy: 0.9294
# Epoch 149/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3064 - accuracy: 0.9730 - val_loss: 0.4801 - val_accuracy: 0.9318
# Epoch 150/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3070 - accuracy: 0.9720 - val_loss: 0.4843 - val_accuracy: 0.9308
# Epoch 151/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3042 - accuracy: 0.9736 - val_loss: 0.4913 - val_accuracy: 0.9289
# Epoch 152/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3018 - accuracy: 0.9731 - val_loss: 0.4789 - val_accuracy: 0.9328
# Epoch 153/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3043 - accuracy: 0.9727 - val_loss: 0.4752 - val_accuracy: 0.9314
# Epoch 154/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.3024 - accuracy: 0.9723 - val_loss: 0.4840 - val_accuracy: 0.9299
# Epoch 155/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.3013 - accuracy: 0.9735 - val_loss: 0.4890 - val_accuracy: 0.9297
# Epoch 156/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2955 - accuracy: 0.9745 - val_loss: 0.4904 - val_accuracy: 0.9284
# Epoch 157/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2925 - accuracy: 0.9751 - val_loss: 0.4729 - val_accuracy: 0.9314
# Epoch 158/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2937 - accuracy: 0.9740 - val_loss: 0.4791 - val_accuracy: 0.9314
# Epoch 159/250
# 390/390 [==============================] - 63s 161ms/step - loss: 0.2935 - accuracy: 0.9734 - val_loss: 0.4790 - val_accuracy: 0.9290
# Epoch 160/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2888 - accuracy: 0.9746 - val_loss: 0.4768 - val_accuracy: 0.9288
# Epoch 161/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2845 - accuracy: 0.9771 - val_loss: 0.4706 - val_accuracy: 0.9319
# Epoch 162/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2844 - accuracy: 0.9767 - val_loss: 0.4678 - val_accuracy: 0.9319
# Epoch 163/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2846 - accuracy: 0.9761 - val_loss: 0.4761 - val_accuracy: 0.9316
# Epoch 164/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2814 - accuracy: 0.9775 - val_loss: 0.4718 - val_accuracy: 0.9335
# Epoch 165/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2788 - accuracy: 0.9778 - val_loss: 0.4704 - val_accuracy: 0.9335
# Epoch 166/250
# 390/390 [==============================] - 64s 164ms/step - loss: 0.2766 - accuracy: 0.9789 - val_loss: 0.4673 - val_accuracy: 0.9335
# Epoch 167/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2722 - accuracy: 0.9797 - val_loss: 0.4694 - val_accuracy: 0.9336
# Epoch 168/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2775 - accuracy: 0.9781 - val_loss: 0.4701 - val_accuracy: 0.9337
# Epoch 169/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2766 - accuracy: 0.9782 - val_loss: 0.4671 - val_accuracy: 0.9332
# Epoch 170/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2739 - accuracy: 0.9784 - val_loss: 0.4676 - val_accuracy: 0.9322
# Epoch 171/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2726 - accuracy: 0.9792 - val_loss: 0.4688 - val_accuracy: 0.9328
# Epoch 172/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2722 - accuracy: 0.9794 - val_loss: 0.4701 - val_accuracy: 0.9335
# Epoch 173/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2700 - accuracy: 0.9795 - val_loss: 0.4663 - val_accuracy: 0.9349
# Epoch 174/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2731 - accuracy: 0.9789 - val_loss: 0.4639 - val_accuracy: 0.9339
# Epoch 175/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2679 - accuracy: 0.9800 - val_loss: 0.4630 - val_accuracy: 0.9346
# Epoch 176/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2661 - accuracy: 0.9805 - val_loss: 0.4717 - val_accuracy: 0.9321
# Epoch 177/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2677 - accuracy: 0.9800 - val_loss: 0.4678 - val_accuracy: 0.9341
# Epoch 178/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2649 - accuracy: 0.9799 - val_loss: 0.4663 - val_accuracy: 0.9340
# Epoch 179/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2683 - accuracy: 0.9794 - val_loss: 0.4771 - val_accuracy: 0.9318
# Epoch 180/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2650 - accuracy: 0.9795 - val_loss: 0.4656 - val_accuracy: 0.9327
# Epoch 181/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2639 - accuracy: 0.9799 - val_loss: 0.4687 - val_accuracy: 0.9323
# Epoch 182/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2618 - accuracy: 0.9810 - val_loss: 0.4690 - val_accuracy: 0.9323
# Epoch 183/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2590 - accuracy: 0.9818 - val_loss: 0.4649 - val_accuracy: 0.9343
# Epoch 184/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2623 - accuracy: 0.9803 - val_loss: 0.4653 - val_accuracy: 0.9345
# Epoch 185/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2611 - accuracy: 0.9808 - val_loss: 0.4654 - val_accuracy: 0.9351
# Epoch 186/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2587 - accuracy: 0.9822 - val_loss: 0.4675 - val_accuracy: 0.9329
# Epoch 187/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2592 - accuracy: 0.9812 - val_loss: 0.4676 - val_accuracy: 0.9342
# Epoch 188/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2587 - accuracy: 0.9818 - val_loss: 0.4659 - val_accuracy: 0.9346
# Epoch 189/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2565 - accuracy: 0.9815 - val_loss: 0.4672 - val_accuracy: 0.9345
# Epoch 190/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2556 - accuracy: 0.9821 - val_loss: 0.4692 - val_accuracy: 0.9334
# Epoch 191/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2570 - accuracy: 0.9817 - val_loss: 0.4675 - val_accuracy: 0.9341
# Epoch 192/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2569 - accuracy: 0.9817 - val_loss: 0.4662 - val_accuracy: 0.9340
# Epoch 193/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2545 - accuracy: 0.9825 - val_loss: 0.4650 - val_accuracy: 0.9338
# Epoch 194/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2557 - accuracy: 0.9821 - val_loss: 0.4643 - val_accuracy: 0.9344
# Epoch 195/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2534 - accuracy: 0.9831 - val_loss: 0.4647 - val_accuracy: 0.9328
# Epoch 196/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2528 - accuracy: 0.9824 - val_loss: 0.4642 - val_accuracy: 0.9341
# Epoch 197/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2545 - accuracy: 0.9822 - val_loss: 0.4673 - val_accuracy: 0.9347
# Epoch 198/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2528 - accuracy: 0.9824 - val_loss: 0.4694 - val_accuracy: 0.9349
# Epoch 199/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2506 - accuracy: 0.9835 - val_loss: 0.4655 - val_accuracy: 0.9347
# Epoch 200/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2517 - accuracy: 0.9828 - val_loss: 0.4670 - val_accuracy: 0.9350
# Epoch 201/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2494 - accuracy: 0.9831 - val_loss: 0.4686 - val_accuracy: 0.9348
# Epoch 202/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2486 - accuracy: 0.9836 - val_loss: 0.4672 - val_accuracy: 0.9352
# Epoch 203/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2515 - accuracy: 0.9826 - val_loss: 0.4670 - val_accuracy: 0.9356
# Epoch 204/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2499 - accuracy: 0.9829 - val_loss: 0.4668 - val_accuracy: 0.9352
# Epoch 205/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2496 - accuracy: 0.9837 - val_loss: 0.4681 - val_accuracy: 0.9349
# Epoch 206/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2480 - accuracy: 0.9838 - val_loss: 0.4667 - val_accuracy: 0.9352
# Epoch 207/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2497 - accuracy: 0.9832 - val_loss: 0.4638 - val_accuracy: 0.9356
# Epoch 208/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2488 - accuracy: 0.9837 - val_loss: 0.4648 - val_accuracy: 0.9351
# Epoch 209/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2500 - accuracy: 0.9824 - val_loss: 0.4653 - val_accuracy: 0.9346
# Epoch 210/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2488 - accuracy: 0.9828 - val_loss: 0.4668 - val_accuracy: 0.9350
# Epoch 211/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2490 - accuracy: 0.9833 - val_loss: 0.4650 - val_accuracy: 0.9361
# Epoch 212/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2467 - accuracy: 0.9834 - val_loss: 0.4648 - val_accuracy: 0.9358
# Epoch 213/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2479 - accuracy: 0.9832 - val_loss: 0.4670 - val_accuracy: 0.9352
# Epoch 214/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2492 - accuracy: 0.9832 - val_loss: 0.4691 - val_accuracy: 0.9346
# Epoch 215/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2469 - accuracy: 0.9834 - val_loss: 0.4665 - val_accuracy: 0.9351
# Epoch 216/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2494 - accuracy: 0.9833 - val_loss: 0.4656 - val_accuracy: 0.9349
# Epoch 217/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2483 - accuracy: 0.9833 - val_loss: 0.4669 - val_accuracy: 0.9350
# Epoch 218/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2442 - accuracy: 0.9847 - val_loss: 0.4644 - val_accuracy: 0.9356
# Epoch 219/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2485 - accuracy: 0.9837 - val_loss: 0.4666 - val_accuracy: 0.9350
# Epoch 220/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2457 - accuracy: 0.9838 - val_loss: 0.4665 - val_accuracy: 0.9350
# Epoch 221/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2448 - accuracy: 0.9847 - val_loss: 0.4650 - val_accuracy: 0.9352
# Epoch 222/250
# 390/390 [==============================] - 64s 164ms/step - loss: 0.2448 - accuracy: 0.9843 - val_loss: 0.4663 - val_accuracy: 0.9342
# Epoch 223/250
# 390/390 [==============================] - 64s 164ms/step - loss: 0.2439 - accuracy: 0.9837 - val_loss: 0.4658 - val_accuracy: 0.9344
# Epoch 224/250
# 390/390 [==============================] - 64s 164ms/step - loss: 0.2464 - accuracy: 0.9836 - val_loss: 0.4649 - val_accuracy: 0.9345
# Epoch 225/250
# 390/390 [==============================] - 64s 164ms/step - loss: 0.2442 - accuracy: 0.9840 - val_loss: 0.4649 - val_accuracy: 0.9349
# Epoch 226/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2436 - accuracy: 0.9845 - val_loss: 0.4651 - val_accuracy: 0.9341
# Epoch 227/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2444 - accuracy: 0.9839 - val_loss: 0.4639 - val_accuracy: 0.9353
# Epoch 228/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2464 - accuracy: 0.9839 - val_loss: 0.4651 - val_accuracy: 0.9344
# Epoch 229/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2431 - accuracy: 0.9845 - val_loss: 0.4646 - val_accuracy: 0.9343
# Epoch 230/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2439 - accuracy: 0.9843 - val_loss: 0.4668 - val_accuracy: 0.9343
# Epoch 231/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2422 - accuracy: 0.9845 - val_loss: 0.4659 - val_accuracy: 0.9344
# Epoch 232/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2433 - accuracy: 0.9845 - val_loss: 0.4666 - val_accuracy: 0.9346
# Epoch 233/250
# 390/390 [==============================] - 67s 173ms/step - loss: 0.2434 - accuracy: 0.9840 - val_loss: 0.4663 - val_accuracy: 0.9350
# Epoch 234/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2415 - accuracy: 0.9850 - val_loss: 0.4647 - val_accuracy: 0.9351
# Epoch 235/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2420 - accuracy: 0.9850 - val_loss: 0.4644 - val_accuracy: 0.9349
# Epoch 236/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2422 - accuracy: 0.9855 - val_loss: 0.4637 - val_accuracy: 0.9347
# Epoch 237/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2424 - accuracy: 0.9843 - val_loss: 0.4637 - val_accuracy: 0.9346
# Epoch 238/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2425 - accuracy: 0.9839 - val_loss: 0.4649 - val_accuracy: 0.9349
# Epoch 239/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2435 - accuracy: 0.9837 - val_loss: 0.4649 - val_accuracy: 0.9346
# Epoch 240/250
# 390/390 [==============================] - 63s 163ms/step - loss: 0.2416 - accuracy: 0.9849 - val_loss: 0.4648 - val_accuracy: 0.9351
# Epoch 241/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2423 - accuracy: 0.9847 - val_loss: 0.4653 - val_accuracy: 0.9348
# Epoch 242/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2391 - accuracy: 0.9856 - val_loss: 0.4655 - val_accuracy: 0.9345
# Epoch 243/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2417 - accuracy: 0.9849 - val_loss: 0.4648 - val_accuracy: 0.9350
# Epoch 244/250
# 390/390 [==============================] - 64s 164ms/step - loss: 0.2419 - accuracy: 0.9845 - val_loss: 0.4652 - val_accuracy: 0.9351
# Epoch 245/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2423 - accuracy: 0.9845 - val_loss: 0.4642 - val_accuracy: 0.9355
# Epoch 246/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2429 - accuracy: 0.9837 - val_loss: 0.4645 - val_accuracy: 0.9352
# Epoch 247/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2397 - accuracy: 0.9852 - val_loss: 0.4644 - val_accuracy: 0.9351
# Epoch 248/250
# 390/390 [==============================] - 63s 162ms/step - loss: 0.2429 - accuracy: 0.9843 - val_loss: 0.4649 - val_accuracy: 0.9351
# Epoch 249/250
# 390/390 [==============================] - 68s 173ms/step - loss: 0.2414 - accuracy: 0.9846 - val_loss: 0.4645 - val_accuracy: 0.9349
# Epoch 250/250
# 390/390 [==============================] - 64s 163ms/step - loss: 0.2418 - accuracy: 0.9848 - val_loss: 0.4630 - val_accuracy: 0.9350
# the validation 0/1 loss is:  0.065

# %% [markdown]
# Saving the Weights of the Model
# ---

# %%
model.save_weights('cifar10.h5')
